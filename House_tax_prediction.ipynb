# %% [markdown]
# <a href="https://colab.research.google.com/github/Jessyjes2003/My_mini_project/blob/main/House_tax_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %matplotlib inline

# %%
data = pd.read_csv('HousingData.csv')
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['CRIM'].plot(kind='hist', bins=20, title='CRIM')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['ZN'].plot(kind='hist', bins=20, title='ZN')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['INDUS'].plot(kind='hist', bins=20, title='INDUS')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['NOX'].plot(kind='hist', bins=20, title='NOX')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='CRIM', y='ZN', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='ZN', y='INDUS', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='INDUS', y='NOX', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='NOX', y='RM', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CHAS']
#   ys = series['CRIM']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('CHAS', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CHAS')
# _ = plt.ylabel('CRIM')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CHAS']
#   ys = series['ZN']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('CHAS', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CHAS')
# _ = plt.ylabel('ZN')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CHAS']
#   ys = series['INDUS']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('CHAS', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CHAS')
# _ = plt.ylabel('INDUS')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CHAS']
#   ys = series['NOX']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('CHAS', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CHAS')
# _ = plt.ylabel('NOX')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['CRIM'].plot(kind='line', figsize=(8, 4), title='CRIM')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['ZN'].plot(kind='line', figsize=(8, 4), title='ZN')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['INDUS'].plot(kind='line', figsize=(8, 4), title='INDUS')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['NOX'].plot(kind='line', figsize=(8, 4), title='NOX')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['CRIM'].plot(kind='hist', bins=20, title='CRIM')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['ZN'].plot(kind='hist', bins=20, title='ZN')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['INDUS'].plot(kind='hist', bins=20, title='INDUS')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['CHAS'].plot(kind='hist', bins=20, title='CHAS')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='CRIM', y='ZN', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='ZN', y='INDUS', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='INDUS', y='CHAS', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23.plot(kind='scatter', x='CHAS', y='NOX', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['CRIM'].plot(kind='line', figsize=(8, 4), title='CRIM')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['ZN'].plot(kind='line', figsize=(8, 4), title='ZN')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['INDUS'].plot(kind='line', figsize=(8, 4), title='INDUS')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['CHAS'].plot(kind='line', figsize=(8, 4), title='CHAS')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.corr()['TAX'].sort_values(ascending=False)
# Out:
# TAX        1.000000
# RAD        0.910228
# INDUS      0.731055
# NOX        0.668023
# CRIM       0.580595
# LSTAT      0.536110
# AGE        0.509114
# PTRATIO    0.460853
# CHAS      -0.032304
# RM        -0.292048
# ZN        -0.312371
# B         -0.441808
# MEDV      -0.468536
# DIS       -0.534432
# Name: TAX, dtype: float64

# %%
col = ['CRIM','ZN','INDUS','CHAS','AGE','LSTAT']
for c in col:
    data[c].fillna(data[c].mean(),inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
from sklearn.preprocessing import StandardScaler

X = data.drop('TAX',axis=1)
y = data['TAX']

scaler = StandardScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

rfc = RandomForestRegressor()
params = {'n_estimators':[100,200,300,400,500,600,700,800,900,1000]}

grid_model = GridSearchCV(rfc, params,verbose=2)
grid_model.fit(X_train,y_train)

pred = grid_model.predict(X_test)

print('Random Forest accuracy is --> ',r2_score(y_test,pred)*100)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ...................................n_estimators=100; total time=   0.2s
# [CV] END ...................................n_estimators=100; total time=   0.2s
# [CV] END ...................................n_estimators=100; total time=   0.2s
# [CV] END ...................................n_estimators=100; total time=   0.2s
# [CV] END ...................................n_estimators=100; total time=   0.2s
# [CV] END ...................................n_estimators=200; total time=   0.5s
# [CV] END ...................................n_estimators=200; total time=   0.5s
# [CV] END ...................................n_estimators=200; total time=   0.5s
# [CV] END ...................................n_estimators=200; total time=   0.5s
# [CV] END ...................................n_estimators=200; total time=   0.5s
# [CV] END ...................................n_estimators=300; total time=   0.7s
# [CV] END ...................................n_estimators=300; total time=   0.7s
# [CV] END ...................................n_estimators=300; total time=   0.7s
# [CV] END ...................................n_estimators=300; total time=   0.7s
# [CV] END ...................................n_estimators=300; total time=   0.8s
# [CV] END ...................................n_estimators=400; total time=   1.5s
# [CV] END ...................................n_estimators=400; total time=   1.3s
# [CV] END ...................................n_estimators=400; total time=   0.9s
# [CV] END ...................................n_estimators=400; total time=   0.9s
# [CV] END ...................................n_estimators=400; total time=   0.9s
# [CV] END ...................................n_estimators=500; total time=   1.2s
# [CV] END ...................................n_estimators=500; total time=   1.2s
# [CV] END ...................................n_estimators=500; total time=   1.2s
# [CV] END ...................................n_estimators=500; total time=   1.2s
# [CV] END ...................................n_estimators=500; total time=   1.2s
# [CV] END ...................................n_estimators=600; total time=   1.5s
# [CV] END ...................................n_estimators=600; total time=   2.1s
# [CV] END ...................................n_estimators=600; total time=   1.5s
# [CV] END ...................................n_estimators=600; total time=   1.4s
# [CV] END ...................................n_estimators=600; total time=   1.4s
# [CV] END ...................................n_estimators=700; total time=   1.6s
# [CV] END ...................................n_estimators=700; total time=   1.6s
# [CV] END ...................................n_estimators=700; total time=   1.6s
# [CV] END ...................................n_estimators=700; total time=   1.8s
# [CV] END ...................................n_estimators=700; total time=   2.3s
# [CV] END ...................................n_estimators=800; total time=   1.9s
# [CV] END ...................................n_estimators=800; total time=   1.8s
# [CV] END ...................................n_estimators=800; total time=   1.9s
# [CV] END ...................................n_estimators=800; total time=   1.8s
# [CV] END ...................................n_estimators=800; total time=   1.8s
# [CV] END ...................................n_estimators=900; total time=   2.9s
# [CV] END ...................................n_estimators=900; total time=   2.1s
# [CV] END ...................................n_estimators=900; total time=   2.1s
# [CV] END ...................................n_estimators=900; total time=   2.1s
# [CV] END ...................................n_estimators=900; total time=   2.0s
# [CV] END ..................................n_estimators=1000; total time=   2.6s
# [CV] END ..................................n_estimators=1000; total time=   3.0s
# [CV] END ..................................n_estimators=1000; total time=   2.5s
# [CV] END ..................................n_estimators=1000; total time=   2.3s
# [CV] END ..................................n_estimators=1000; total time=   2.3s
# Random Forest accuracy is -->  97.8649997422931

# %%
grid_model.best_params_
# Out:
# {'n_estimators': 300}

# %%
res = pd.DataFrame()
res['Y_Test'] = y_test
res['PRED'] = pred
res.head()
# Out:
#      Y_Test        PRED
# 173     296  371.676667
# 274     254  257.546667
# 491     711  675.346667
# 72      305  306.873333
# 452     666  666.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['Y_Test'].plot(kind='hist', bins=20, title='Y_Test')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['PRED'].plot(kind='hist', bins=20, title='PRED')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='Y_Test', y='PRED', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_31['Y_Test'].plot(kind='line', figsize=(8, 4), title='Y_Test')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_32['PRED'].plot(kind='line', figsize=(8, 4), title='PRED')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
sns.scatterplot(y_test)
sns.scatterplot(pred)
plt.xlabel('real values')
plt.ylabel('predicted values')
# Out:
# Text(0, 0.5, 'predicted values')
